# %%
import logging

from marmopose.version import __version__ as marmopose_version
from marmopose.config import Config
from marmopose.processing.prediction import Predictor
from marmopose.visualization.display_2d import Visualizer2D
from marmopose.visualization.display_3d import Visualizer3D
from marmopose.processing.triangulation import Reconstructor3D

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(name)s - %(message)s')
logger = logging.getLogger(__name__)

logger.info(f'MarmoPose version: {marmopose_version}')
# Out:
# 2026-05-09 10:30:16,746 - INFO - __main__ - MarmoPose version: 1.2.2
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
# Path to the configuration file
config_path = '../configs/default.yaml'
# config_path = 'C:/Users/issac/Documents/MarmoPose/configs/default.yaml'

# Configuration setup
# You can either modify the parameters directly in the YAML configuration file (default.yaml),
# or override specific parameters directly in the code below, as shown.
config = Config(
    config_path=config_path,
    
    # The following parameters override those in the default.yaml file
    n_tracks=2, 

    project='../demos/pair',
    det_model='../models/detection_model',
    pose_model='../models/pose_model',
    dae_model='../models/dae_model',

    dae_enable=True,
    do_optimize=True
)
# Out:
# 2026-05-09 10:39:59,011 - INFO - marmopose.config - *** Overriding config *** | n_tracks: 2 -> 2
# 2026-05-09 10:39:59,011 - INFO - marmopose.config - *** Overriding config *** | project: ../demos/pair -> ../demos/pair
# 2026-05-09 10:39:59,012 - INFO - marmopose.config - *** Overriding config *** | det_model: ../models/detection_model -> ../models/detection_model
# 2026-05-09 10:39:59,012 - INFO - marmopose.config - *** Overriding config *** | pose_model: ../models/pose_model -> ../models/pose_model
# 2026-05-09 10:39:59,013 - INFO - marmopose.config - *** Overriding config *** | dae_model: ../models/dae_model -> ../models/dae_model
# 2026-05-09 10:39:59,013 - INFO - marmopose.config - *** Overriding config *** | dae_enable: True -> True
# 2026-05-09 10:39:59,014 - INFO - marmopose.config - *** Overriding config *** | do_optimize: True -> True

# %%
# Run 2D prediction
predictor = Predictor(config, batch_size=4)
predictor.predict()
# Out:
# 2026-05-09 10:40:04,388 - INFO - marmopose.processing.prediction - Predictor device: cuda | batch size: 4
# 2026-05-09 10:40:04,390 - INFO - marmopose.processing.prediction - Load detection model config from ..\models\detection_model\config.py
# 2026-05-09 10:40:04,391 - INFO - marmopose.processing.prediction - Load detection model checkpoint from ..\models\detection_model\best.pth
# Loads checkpoint by local backend from path: ..\models\detection_model\best.pth
# 2026-05-09 10:40:06,354 - INFO - marmopose.processing.prediction - Load pose model config from ..\models\pose_model\config.py
# 2026-05-09 10:40:06,355 - INFO - marmopose.processing.prediction - Load pose model checkpoint from ..\models\pose_model\best.pth
# Loads checkpoint by local backend from path: ..\models\pose_model\best.pth

# %%
# Run 3D triangulation and (optional) optimization 
reconstructor_3d = Reconstructor3D(config)
reconstructor_3d.triangulate()

# %%
# Visualize 2D results if needed
visualizer_2d = Visualizer2D(config)
visualizer_2d.generate_videos_2d()

# %%
# Visualize 3D results if needed
visualizer_3d = Visualizer3D(config)

# source_3d: 'original' indicates the 3D poses before optimization, 'optimized' indicates the 3D poses after optimization
# video_type: 'composite' indicates the 3D video is composited with 2D video, '3d' indicates only 3D video is shown; generating 'composite' video is about 2x slower than just '3d' video
visualizer_3d.generate_video_3d(source_3d='optimized', start_frame_idx=0, end_frame_idx=None, video_type='composite')

# visualizer_3d.generate_video_3d(source_3d='original', video_type='composite')
# visualizer_3d.generate_video_3d(source_3d='original', video_type='3d')
# visualizer_3d.generate_video_3d(source_3d='optimized', video_type='3d')
